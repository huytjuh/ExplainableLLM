# %% [markdown]
# # Sampling Strategies
# Compare greedy and sampled decoding.

# %%
import sys
sys.path.insert(0, '../src/02_transformer')
from inference import sample_next_token
sample_next_token([2.0, 1.0, 0.1], temperature=0.7, top_k=2)
