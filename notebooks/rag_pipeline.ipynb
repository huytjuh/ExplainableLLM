# %% [markdown]
# # RAG Pipeline
# Build a local vector index and retrieve context.

# %%
import sys
sys.path.insert(0, '../src/04_RAG')
from S03_embeddings import HashingEmbeddingModel
from S04_indexing import InMemoryVectorStore
model = HashingEmbeddingModel()
store = InMemoryVectorStore()
store.add('a', 'RAG retrieves context.', model.embed('RAG retrieves context.'))
store.search(model.embed('retrieval context'))
