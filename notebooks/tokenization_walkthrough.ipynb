# %% [markdown]
# # Tokenization Walkthrough
# Use `SimpleTokenizer` to inspect tokens and ids.

# %%
import sys
sys.path.insert(0, '../src/02_transformer')
from tokenizer import SimpleTokenizer
tokenizer = SimpleTokenizer().fit(['LLMs generate tokens.'])
tokenizer.encode('LLMs generate tokens.')
