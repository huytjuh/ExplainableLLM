# %% [markdown]
# # Transformer Forward Pass
# Trace a tiny decoder block.

# %%
import sys
sys.path.insert(0, '../src/02_transformer')
from transformer import TinyDecoderBlock
block = TinyDecoderBlock()
block.forward([[1.0, 0.0], [0.0, 1.0]])
